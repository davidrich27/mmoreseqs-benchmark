# %% [markdown]
# ## ROC Plot: HMMER vs MMseqs vs MMseqs+fb-pruner

# %%
#imports
from __future__ import print_function
import sys
import os
import psutil
import math
import numpy as np
import pandas as pd
import cv2 as cv
from PIL import Image
from IPython.display import display
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import statsmodels.api as sm
import statistics as stats

# %%
# number or rows/columns to display
pd.options.display.max_rows = 40
pd.options.display.max_columns = 20

# resolution of output
matplotlib.rcParams['figure.dpi'] = 300

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 6 }

matplotlib.rc('font', **font)

# %%
# root directory
path_to_db = "data/soeding/"

# %%
# index filepaths
target_index_fname = "{}/pmark.hmm.idx".format(path_to_db)
query_index_fname = "{}/pmark.fa.idx".format(path_to_db)

# %%
# data filepaths
hmmer_fname = "{}/hmmer_n1.soeding.tf".format(path_to_db)

mmseqs_k95_fname = "{}/mmseqs_n1.soeding.k95.tf".format(path_to_db)
mmseqs_k80_fname = "{}/mmseqs_n1.soeding.k80.tf".format(path_to_db)
mmseqs_k75_fname = "{}/mmseqs_n1.soeding.k75.tf".format(path_to_db)

params = "12.16.5.001"
fbpruner_k95_cut_fname = "{}/mmseqs_plus.soeding.k95.cut.{}.tf".format(path_to_db, params)
fbpruner_k95_all_fname = "{}/mmseqs_plus.soeding.k95.all.{}.tf".format(path_to_db, params)
fbpruner_k80_cut_fname = "{}/mmseqs_plus.soeding.k80.cut.{}.tf".format(path_to_db, params)
fbpruner_k80_all_fname = "{}/mmseqs_plus.soeding.k80.all.{}.tf".format(path_to_db, params)
fbpruner_k75_cut_fname = "{}/mmseqs_plus.soeding.k75.cut.{}.tf".format(path_to_db, params)
fbpruner_k75_all_fname = "{}/mmseqs_plus.soeding.k75.all.{}.tf".format(path_to_db, params)

# %%
# Total Queries and Targets
total_target       = 30430281
total_query        =     6370
total_target_real  =  3374007
total_target_decoy = 27056274
# Total True Positives and Negatives
total_res = 193840889970
total_TP  =     33344127
total_TN  = 172348465380
unknown   =  21459080463
TP_to_TN  =     1.93e-04

# %%
# runtimes

# hmmer
hmmer_times = {}
hmmer_times["search"]    = 908105.50
hmmer_times["total"]     = hmmer_times["search"]
# mmseqs
mmseqs_times = {}
mmseqs_build         =   8837.23
mmseqs_times["k95"]  =   1198.97 + mmseqs_build
mmseqs_times["k80"]  = 230723.07 + mmseqs_build
mmseqs_times["k75"]  = 328972.96 + mmseqs_build
# fbpruner
fbpruner_times = {}
fbpruner_times["index"]     = 14.0
fbpruner_times["build"]     = 0.0
fbpruner_build              = fbpruner_times["index"] + fbpruner_times["build"]
fbpruner_times["k95-cut"]   = 28879.48 + fbpruner_build + mmseqs_times["k95"]
fbpruner_times["k95-all"]   = 28682.03 + fbpruner_build + mmseqs_times["k95"]
fbpruner_times["k80-cut"]   = 21705.58 + fbpruner_build + mmseqs_times["k80"]
fbpruner_times["k80-all"]   = 31121.06 + fbpruner_build + mmseqs_times["k80"]
fbpruner_times["k75-cut"]   = 22067.56 + fbpruner_build + mmseqs_times["k75"]
fbpruner_times["k75-all"]   = 38224.11 + fbpruner_build + mmseqs_times["k75"]

# %% [markdown]
# # load data

# %%
datas = []

# set header format
tf_dformat = {
    "target_name": "str",
    "query_name": "str",
    "eval": "float",
    "truth": "str",
    "tot_T": "int",
    "tot_F": "int",
    "tot_?": "int"
}
tf_header = tf_dformat.keys()

# load data
usecols = [0,1,2,3,4,5]
skiprows = None
sep = " "
names = tf_header

# %%
hmmer_data = pd.read_csv( hmmer_fname, sep=sep, header=None, skiprows=skiprows, usecols=usecols, names=names, index_col=False, verbose=False )
datas.append(hmmer_data)
hmmer_data
# Out:
#       target_name              query_name     eval truth    tot_T    tot_F
# 0        O26359_1        annotated_O26359      0.0     T      100        0
# 1        P04050_1    annotated_A0A024MVN1      0.0     T      200        0
# 2        P05091_1        annotated_P47738      0.0     T      300        0
# 3        P08394_1        annotated_R9PMJ0      0.0     T      400        0
# 4        P0A110_1        annotated_P0A110      0.0     T      500        0
# ...           ...                     ...      ...   ...      ...      ...
# 96432    O43001_1  tr|F6J1X5|F6J1X5_DROME  10000.0     F  7139703  2028797
# 96433    P15291_1  tr|F8K1A0|F8K1A0_STREN  10000.0     F  7139708  2028875
# 96434    P54728_1    annotated_A0A031HVA5  10000.0     ?  7139711  2028964
# 96435    Q80WW9_1  tr|D2V4T9|D2V4T9_NAEGR  10000.0     F  7139718  2029049
# 96436    T0NKS4_1  tr|F7LG62|F7LG62_BACOV  10000.0     F  7139719  2029138
#
# [96437 rows x 6 columns]

# %%
mmseqs_k95_data = pd.read_csv( mmseqs_k95_fname, sep=sep, header=None, skiprows=skiprows, usecols=usecols, names=names, index_col=False, verbose=False )
datas.append(mmseqs_k95_data)
mmseqs_k95_data
# Out:
#       target_name            query_name    eval truth    tot_T    tot_F
# 0        P04050_1      annotated_A5DCV3     0.0     T      100        0
# 1        P08170_1      annotated_P08170     0.0     T      200        0
# 2        P11216_1  annotated_A0A0B1PHM3     0.0     T      300        0
# 3        P30958_1      annotated_P45128     0.0     T      400        0
# 4        Q00610_1      annotated_H0WIF6     0.0     T      500        0
# ...           ...                   ...     ...   ...      ...      ...
# 54224    Q9IVA5_1      annotated_A8PS46  2020.0     T  3384596  1653718
# 54225    Q9IVA5_1                I7SXE6  2020.0     F  3384611  1653800
# 54226    Q9X0A3_1                B8MZE8  2020.0     F  3384612  1653871
# 54227    Q9X0A3_1                J2XFF6  2020.0     F  3384612  1653971
# 54228    V9R4S8_1                I7UN59  2020.0     F  3384612  1654061
#
# [54229 rows x 6 columns]

# %%
mmseqs_k80_data = pd.read_csv( mmseqs_k80_fname, sep=sep, header=None, skiprows=skiprows, usecols=usecols, names=names, index_col=False, verbose=False )
datas.append(mmseqs_k80_data)
mmseqs_k80_data
# Out:
#       target_name            query_name    eval truth    tot_T    tot_F
# 0        P04050_1  annotated_A0A023AZW7     0.0     T      100        0
# 1        P06971_1      annotated_P06971     0.0     T      200        0
# 2        P09152_1      annotated_A8M8C3     0.0     T      300        0
# 3        P20906_1      annotated_P20906     0.0     T      400        0
# 4        P51691_1      annotated_P51691     0.0     T      500        0
# ...           ...                   ...     ...   ...      ...      ...
# 58021    Q9IVA5_1  annotated_A0A0C5VKQ7  2020.0     T  3676784  1724845
# 58022    Q9IVA5_1                I7PX47  2020.0     F  3676804  1724920
# 58023    Q9X0A3_1                B4ULP9  2020.0     F  3676805  1724991
# 58024    Q9X0A3_1                J2R426  2020.0     F  3676805  1725091
# 58025    V9R4S8_1                I7SMA3  2020.0     F  3676805  1725178
#
# [58026 rows x 6 columns]

# %%
mmseqs_k75_data = pd.read_csv( mmseqs_k75_fname, sep=sep, header=None, skiprows=skiprows, usecols=usecols, names=names, index_col=False, verbose=False )
datas.append(mmseqs_k75_data)
mmseqs_k75_data
# Out:
#         target_name        query_name    eval truth    tot_T    tot_F
# 0          P04050_1  annotated_A7TTU2     0.0     T      100        0
# 1          P07648_1  annotated_R5WAI2     0.0     T      200        0
# 2          P09152_1  annotated_W1G7D5     0.0     T      300        0
# 3          P23395_1  annotated_P23395     0.0     T      400        0
# 4          P90585_1  annotated_Q105B7     0.0     T      500        0
# ...             ...               ...     ...   ...      ...      ...
# 66770      Q8U561_1            F9G2H7  9994.0     F  3168879  2878578
# 66771      Q8XAN4_1  annotated_W0SEA2  9994.0     ?  3168880  2878646
# 66772      Q8XAN4_1            Q61E36  9994.0     F  3168880  2878745
# 66773  A0A0A8URD0_1            H2Y4C9  9995.0     F  3168880  2878828
# 66774      P35568_1            B8B115  9996.0     F  3168884  2878904
#
# [66775 rows x 6 columns]

# %%
fbpruner_k95_cut_data = pd.read_csv( fbpruner_k95_cut_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k95_cut_data)
fbpruner_k95_cut_data
# Out:
#         target_name            query_name        eval truth    tot_T   tot_F
# 0      A0A016QNX0_1      annotated_D2BR32         0.0     T      100       0
# 1      A0A016QNX0_1      annotated_P56904         0.0     T      200       0
# 2      A0A021X368_1  annotated_A0A060QG94         0.0     T      300       0
# 3      A0A023W5H0_1      annotated_Q76Z74         0.0     T      400       0
# 4      A0A024HLX1_1      annotated_C5ZZD4         0.0     T      500       0
# ...             ...                   ...         ...   ...      ...     ...
# 30479      Q5SI12_1                H0RH28    140000.0     F  2864169  127825
# 30480      Q3E841_1                H9GGK2    200000.0     F  2864208  127875
# 30481      Q9X0X3_1      annotated_D9RTF9    280000.0     T  2864249  127905
# 30482      P0C2S3_1  annotated_A0A099P0C3    660000.0     T  2864300  127943
# 30483      P11717_1                A0CPY6  30000000.0     F  2864351  127978
#
# [30484 rows x 6 columns]

# %%
fbpruner_k95_all_data = pd.read_csv( fbpruner_k95_all_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k95_all_data)
fbpruner_k95_all_data
# Out:
#         target_name            query_name        eval truth    tot_T    tot_F
# 0      A0A016QNX0_1      annotated_D2BR32         0.0     T      100        0
# 1      A0A016QNX0_1      annotated_P56904         0.0     T      200        0
# 2      A0A021X368_1  annotated_A0A060QG94         0.0     T      300        0
# 3      A0A023W5H0_1      annotated_Q76Z74         0.0     T      400        0
# 4      A0A024HLX1_1      annotated_C5ZZD4         0.0     T      500        0
# ...             ...                   ...         ...   ...      ...      ...
# 66769      P43555_1                Q7PXZ5   5200000.0     F  3168867  2878574
# 66770      Q8CZ42_1      annotated_H0ZWF3   6100000.0     ?  3168872  2878642
# 66771      Q9X005_1      annotated_Q2BIG0   7900000.0     ?  3168875  2878707
# 66772      P43772_1                Q5LPY0  11000000.0     F  3168878  2878767
# 66773      P13596_1                Q49IZ2  23000000.0     F  3168880  2878839
#
# [66774 rows x 6 columns]

# %%
fbpruner_k80_cut_data = pd.read_csv( fbpruner_k80_cut_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k80_cut_data)
fbpruner_k80_cut_data
# Out:
#         target_name            query_name        eval truth    tot_T   tot_F
# 0      A0A016QNX0_1      annotated_D2BR32         0.0     T      100       0
# 1      A0A016QNX0_1      annotated_P56904         0.0     T      200       0
# 2      A0A021X368_1  annotated_A0A072BXG1         0.0     T      300       0
# 3      A0A024HLX1_1  annotated_A0A074MKQ9         0.0     T      400       0
# 4      A0A024HLX1_1      annotated_E3YS94         0.0     T      500       0
# ...             ...                   ...         ...   ...      ...     ...
# 37517      P03001_1      annotated_Q6AX11    110000.0     T  3390501  267682
# 37518      P80561_1      annotated_K1QWW6    140000.0     T  3390536  267734
# 37519      P42938_1      annotated_M4FDA7    210000.0     T  3390562  267785
# 37520      G5E9X3_1      annotated_B0WWC8    390000.0     T  3390607  267826
# 37521      P12724_1      annotated_P00659  30000000.0     T  3390665  267855
#
# [37522 rows x 6 columns]

# %%
fbpruner_k80_all_data = pd.read_csv( fbpruner_k80_all_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k80_all_data)
fbpruner_k80_all_data
# Out:
#         target_name            query_name       eval truth    tot_T    tot_F
# 0      A0A016QNX0_1      annotated_D2BR32        0.0     T      100        0
# 1      A0A016QNX0_1      annotated_P56904        0.0     T      200        0
# 2      A0A021X368_1  annotated_A0A072BXG1        0.0     T      300        0
# 3      A0A024HLX1_1  annotated_A0A074MKQ9        0.0     T      400        0
# 4      A0A024HLX1_1      annotated_E3YS94        0.0     T      500        0
# ...             ...                   ...        ...   ...      ...      ...
# 58020      Q1IYU4_1                A4I3D5   630000.0     F  3676727  1724882
# 58021      P01636_1      annotated_S7MF52   780000.0     T  3676742  1724948
# 58022      P01636_1      annotated_W8BIV4  1000000.0     T  3676761  1725005
# 58023      Q5SJ45_1      annotated_Q98RB6  1500000.0     T  3676775  1725065
# 58024      P35613_1      annotated_H2M9R6  3100000.0     T  3676792  1725124
#
# [58025 rows x 6 columns]

# %%
fbpruner_k75_cut_data = pd.read_csv( fbpruner_k75_cut_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k75_cut_data)
fbpruner_k75_cut_data
# Out:
#         target_name            query_name       eval truth    tot_T    tot_F
# 0      A0A016QNX0_1      annotated_D2BR32        0.0     T      100        0
# 1      A0A016QNX0_1      annotated_P56904        0.0     T      200        0
# 2      A0A021X368_1  annotated_A0A060QG94        0.0     T      300        0
# 3      A0A024HLX1_1  annotated_A0A090RTW5        0.0     T      400        0
# 4      A0A024HLX1_1      annotated_Q0K464        0.0     T      500        0
# ...             ...                   ...        ...   ...      ...      ...
# 54223      Q5U780_1      annotated_M1MT18   620000.0     T  3384546  1653763
# 54224      H0X821_1                B4K598   790000.0     F  3384560  1653826
# 54225      Q01693_1                Q9M3G7  1000000.0     F  3384573  1653887
# 54226      Q5SJ45_1      annotated_Q98RB6  1500000.0     T  3384584  1653948
# 54227      P17169_1      annotated_C7QF66  3100000.0     T  3384599  1654006
#
# [54228 rows x 6 columns]

# %%
fbpruner_k75_all_data = pd.read_csv( fbpruner_k75_all_fname, sep=sep, header=None, skiprows=skiprows, usecols = usecols, names=names, index_col=False, verbose=False, error_bad_lines=False )
datas.append(fbpruner_k75_all_data)
fbpruner_k75_all_data
# Out:
#         target_name            query_name       eval truth    tot_T    tot_F
# 0      A0A016QNX0_1      annotated_D2BR32        0.0     T      100        0
# 1      A0A016QNX0_1      annotated_P56904        0.0     T      200        0
# 2      A0A021X368_1  annotated_A0A060QG94        0.0     T      300        0
# 3      A0A024HLX1_1  annotated_A0A090RTW5        0.0     T      400        0
# 4      A0A024HLX1_1      annotated_Q0K464        0.0     T      500        0
# ...             ...                   ...        ...   ...      ...      ...
# 54223      Q5U780_1      annotated_M1MT18   620000.0     T  3384546  1653763
# 54224      H0X821_1                B4K598   790000.0     F  3384560  1653826
# 54225      Q01693_1                Q9M3G7  1000000.0     F  3384573  1653887
# 54226      Q5SJ45_1      annotated_Q98RB6  1500000.0     T  3384584  1653948
# 54227      P17169_1      annotated_C7QF66  3100000.0     T  3384599  1654006
#
# [54228 rows x 6 columns]

# %%
for data in datas:
    data["roc_y"] = data["tot_T"] / total_TP
    data["roc_x"] = data["tot_F"] / total_query

# %%
my_data = [ hmmer_data, mmseqs_k95_data, mmseqs_k80_data, mmseqs_k75_data,  fbpruner_k95_all_data, fbpruner_k95_cut_data, fbpruner_k80_all_data, fbpruner_k75_all_data, fbpruner_k75_cut_data ]
colors  = [ 'red', 'lightgreen', 'green', 'darkgreen', 'blue', 'darkblue', 'blue', 'blue', 'darkblue' ]
labels  = [ 'hmmer', 'mmseqs-k95', 'mmseqs-k80', 'mmseqs-k75', 'fbpruner-k95-all', 'fbpruner-k95-cut', 'fbpruner-k80-all', 'fbpruner-k75-all', 'fbpruner-k75-cut' ]

for x in range(len(my_data)):
    plt.plot( my_data[x]["roc_x"], my_data[x]["roc_y"], color=colors[x], label=labels[x], linestyle="--", marker=None )

plt.title('ROC Plot')
plt.legend(loc='lower right')
plt.ylabel('Percent of True Positives Recovered')
plt.xlabel('Number of False Positives Recovered (Average per Query)')
plt.xscale('log')
plt.savefig("visuals/mmseqs-hmmer-fbpruner-roc-plot.jpg")
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
my_data = [ hmmer_data, mmseqs_k95_data, mmseqs_k80_data, mmseqs_k75_data,  fbpruner_k95_all_data, fbpruner_k80_all_data, fbpruner_k75_all_data ]
colors  = [ 'red', 'lightgreen', 'green', 'darkgreen', 'lightblue', 'blue', 'darkblue' ]
labels  = [ 'hmmer', 'mmseqs-k95', 'mmseqs-k80', 'mmseqs-k75', 'fbpruner-k95-all', 'fbpruner-k80-all', 'fbpruner-k75-all' ]

for x in range(len(my_data)):
    plt.plot( my_data[x]["roc_x"], my_data[x]["roc_y"], color=colors[x], label=labels[x], linestyle="--", marker=None )

plt.title('ROC Plot')
plt.legend(loc='lower right')
plt.ylabel('Percent of True Positives Recovered')
plt.xlabel('Number of False Positives Recovered (Average per Query)')
plt.xscale('log')
plt.savefig("visuals/mmseqs-hmmer-fbpruner-roc-plot.jpg")
plt.show()

# %%
my_data = [ hmmer_data, mmseqs_k95_data, mmseqs_k80_data, mmseqs_k75_data,  fbpruner_k95_all_data, fbpruner_k80_all_data, fbpruner_k75_all_data ]
colors  = [ 'red', 'lightgreen', 'green', 'darkgreen', 'lightblue', 'blue', 'darkblue' ]
labels  = [ 'hmmer', 'mmseqs-k95', 'mmseqs-k80', 'mmseqs-k75', 'fbpruner-k95-all', 'fbpruner-k80-all', 'fbpruner-k75-all' ]

for x in range(len(my_data)):
    plt.plot( my_data[x]["roc_x"], my_data[x]["roc_y"], color=colors[x], label=labels[x], linestyle="--", marker=None )

plt.title('ROC Plot')
plt.legend(loc='lower right')
plt.ylabel('Percent of True Positives Recovered')
plt.xlabel('Number of False Positives Recovered (Average per Query)')
plt.xscale('log')
plt.savefig("visuals/mmseqs-hmmer-fbpruner-roc-plot.jpg")
plt.show()

# %%
my_data = [ hmmer_data, mmseqs_k95_data, mmseqs_k80_data, mmseqs_k75_data ]
colors  = [ 'red', 'lightgreen', 'green', 'darkgreen' ]
labels  = [ 'hmmer', 'mmseqs-k95', 'mmseqs-k80', 'mmseqs-k75' ]

for x in range(len(my_data)):
    plt.plot( my_data[x]["roc_x"], my_data[x]["roc_y"], color=colors[x], label=labels[x], linestyle="--", marker=None )

plt.title('ROC Plot')
plt.legend(loc='lower right')
plt.ylabel('Percent of True Positives Recovered')
plt.xlabel('Number of False Positives Recovered (Average per Query)')
plt.xscale('log')
plt.savefig("visuals/mmseqs-hmmer-fbpruner-roc-plot.jpg")
plt.show()

# %%
my_data = [ hmmer_data, mmseqs_k95_data, fbpruner_k95_all_data, fbpruner_k95_cut_data ]
colors  = [ 'red', 'darkgreen', 'blue', 'darkblue' ]
labels  = [ 'hmmer', 'mmseqs-k95', 'fbpruner-k95-all', 'fbpruner-k95-cut' ]

for x in range(len(my_data)):
    plt.plot( my_data[x]["roc_x"], my_data[x]["roc_y"], color=colors[x], label=labels[x], linestyle="--", marker=None )

plt.title('ROC Plot')
plt.legend(loc='lower right')
plt.ylabel('Percent of True Positives Recovered')
plt.xlabel('Number of False Positives Recovered (Average per Query)')
plt.xscale('log')
plt.savefig("visuals/mmseqs-hmmer-fbpruner-roc-plot.jpg")
plt.show()

# %% [markdown]
# ## Runtimes

# %%
# compare mmseqs sensitivity runtimes
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
xlabels = ['mmseqs-norm', 'mmseqs-sens', 'mmseqs-preplus', 'hmmer']
colors= ['lightgreen', 'green', 'darkgreen', 'red']
scalar = mmseqs_times['k95']
data = [ mmseqs_times['k95'], mmseqs_times['k80'], mmseqs_times['k75'], hmmer_times['total'] ]
ax.bar(xlabels, data, color=colors)
plt.ylabel('Runtime (in Seconds)')
plt.xlabel('Search Method')
plt.show()

# %%
# compare mmseqs sensitivity runtimes
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
xlabels = ['fb-norm-cut', 'fb-norm-all', 'fb-sense-cut', 'fb-sense-all', 'fb-plus-cut', 'fb-plus-all', 'hmmer']
colors= ['green', 'darkgreen', 'yellow', 'orange', 'blue', 'darkblue', 'red']
scalar = mmseqs_times['k95']
data_top = [ fbpruner_times['k95-cut'], fbpruner_times['k95-all'], fbpruner_times['k80-cut'], fbpruner_times['k80-all'], fbpruner_times['k75-cut'], fbpruner_times['k75-all'], hmmer_times['total'] ]
data_btm = [ mmseqs_times['k95'], mmseqs_times['k95'],  mmseqs_times['k80'], mmseqs_times['k80'], mmseqs_times['k75'], mmseqs_times['k75'], 0 ]
ax.bar(xlabels, data_top, color=colors)
ax.bar(xlabels, data_btm, color='black', alpha=0.6 )
plt.ylabel('Runtime (in Seconds)')
plt.xlabel('Search Method')
plt.show()
